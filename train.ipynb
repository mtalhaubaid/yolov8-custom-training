# %%
import os
os.environ["KMP_DUPLICATE_LIB_OK"]="TRUE"

# %%
from ultralytics import YOLO
# Load the model.
model = YOLO('yolov8n.pt')

# %%
# Training.
results = model.train(
   data='data_TD_Items_5_Cls.yaml',
   imgsz=800,
   epochs=1000,
   batch=80,
   name='TD_Items_5_glasses_updated'
)
# Out:
# New https://pypi.org/project/ultralytics/8.0.205 available  Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.170  Python-3.10.9 torch-2.0.0 CUDA:0 (NVIDIA GeForce RTX 3090, 24575MiB)
# ...

# %%
#resume the training
from ultralytics import YOLO
model = YOLO(r'D:\code\yolov8-custom-training\runs\detect\TD_Items_5_glasses_updated\weights\last.pt')
model.resume = True
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[3], line 3
#       1 #resume the training
#       2 from ultralytics import YOLO
# ----> 3 model = YOLO(r'D:\code\yolov8-custom-training\runs\detect\TD_Items_5_glasses_updated\weights\last.pt')
#       4 model.resume = True
#
# File c:\Users\ASDF\anaconda3\lib\site-packages\ultralytics\engine\model.py:92, in Model.__init__(self, model, task)
#      90     self._new(model, task)
#      91 else:
# ---> 92     self._load(model, task)
#
# File c:\Users\ASDF\anaconda3\lib\site-packages\ultralytics\engine\model.py:138, in Model._load(self, weights, task)
#     136 suffix = Path(weights).suffix
#     137 if suffix == '.pt':
# --> 138     self.model, self.ckpt = attempt_load_one_weight(weights)
#     139     self.task = self.model.args['task']
#     140     self.overrides = self.model.args = self._reset_ckpt_args(self.model.args)
# ...
